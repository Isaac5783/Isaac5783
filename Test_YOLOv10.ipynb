# %% [markdown]
# <a href="https://colab.research.google.com/github/Isaac5783/Isaac5783/blob/main/Test_YOLOv10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Unzip the dataset
# !unzip /content/drive/MyDrive/custom_dataset_copy.zip -d /content/dataset
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/MyDrive/custom_dataset_copy.zip
#    creating: /content/dataset/custom_dataset copy/
#   inflating: /content/dataset/__MACOSX/._custom_dataset copy
#    creating: /content/dataset/custom_dataset copy/valid/
#   inflating: /content/dataset/__MACOSX/custom_dataset copy/._valid
#   inflating: /content/dataset/custom_dataset copy/.DS_Store
#   inflating: /content/dataset/__MACOSX/custom_dataset copy/._.DS_Store
#    creating: /content/dataset/custom_dataset copy/test/
#   inflating: /content/dataset/__MACOSX/custom_dataset copy/._test
#    creating: /content/dataset/custom_dataset copy/train/
#   inflating: /content/dataset/__MACOSX/custom_dataset copy/._train
#   inflating: /content/dataset/custom_dataset copy/valid/Cars193_png.rf.bce722981f582267ded6824518d48095.txt
#   inflating: /content/dataset/__MACOSX/custom_dataset copy/valid/._Cars193_png.rf.bce722981f582267ded6824518d48095.txt
# ...

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20304, done.
# remote: Counting objects: 100% (1502/1502), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 20304 (delta 1438), reused 1348 (delta 1348), pack-reused 18802
# Receiving objects: 100% (20304/20304), 11.17 MiB | 12.49 MiB/s, done.
# Resolving deltas: 100% (14314/14314), done.

# %%
cd yolov10
# Out:
# /content/yolov10

# %%
# !pip install .
# Out:
# Processing /content/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
import os
import urllib.request

# %%
#to create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), 'weights')
os.makedirs(weights_dir, exist_ok=True)

#URLs of the weight files

urls = [
    'https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt',
    'https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt',
    'https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt',
    'https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt',
    'https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt',
    'https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt'
]

#Download each file

for url in urls:
  file_name= os.path.join(weights_dir, os.path.basename(url))
  urllib.request.urlretrieve(url, file_name)
  print(f"Download {file_name}")
# Out:
# Download /content/yolov10/weights/yolov10n.pt
# Download /content/yolov10/weights/yolov10s.pt
# Download /content/yolov10/weights/yolov10m.pt
# Download /content/yolov10/weights/yolov10b.pt
# Download /content/yolov10/weights/yolov10l.pt
# Download /content/yolov10/weights/yolov10x.pt

# %%
import yaml

data = {
    'path': '/content/dataset/custom_dataset',
    'train': 'train',
    'val': 'valid',
    'test': 'test',
    'nc': 1,
    'names': ['licence']
}

with open('/content/dataset/custom_dataset/data.yaml', 'w') as file:
    yaml.dump(data, file)

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model=/content/yolov10/weights/yolov10n.pt data=/content/dataset/custom_dataset/data.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.2.52 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=predict model=/content/yolov10/runs/detect/train/weights/best.pt conf=0.55 source=/content/dataset/custom_dataset/test/
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv10n summary (fused): 285 layers, 2694806 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/30 /content/dataset/custom_dataset/test/Cars100_png.rf.59ab65fb1cd60b07568305c878ab6b58.jpg: 448x640 (no detections), 382.8ms
# image 2/30 /content/dataset/custom_dataset/test/Cars103_png.rf.c1396fe10252ededea5f35d8e83fb890.jpg: 320x640 (no detections), 188.0ms
# image 3/30 /content/dataset/custom_dataset/test/Cars112_png.rf.6b7577d9914980079f0761451ffe5b40.jpg: 640x384 1 licence, 253.0ms
# image 4/30 /content/dataset/custom_dataset/test/Cars175_png.rf.72f493b8203402b36fd1b4f352f4aad9.jpg: 480x640 1 licence, 299.0ms
# image 5/30 /content/dataset/custom_dataset/test/Cars176_png.rf.695b57c7eed67dd6807e5c1f957e38b4.jpg: 416x640 1 licence, 272.2ms
# image 6/30 /content/dataset/custom_dataset/test/Cars188_png.rf.e985dda16f6c6af06b65a429bd7f8624.jpg: 640x480 (no detections), 282.4ms
# ...

# %%
# !cp -r /content/yolov10/runs/detect/predict /content/drive/MyDrive/yolov10n/output/images

# %%
# !cp -r /content/yolov10/runs/detect/train /content/drive/MyDrive/yolov10n/training_backup/licence
